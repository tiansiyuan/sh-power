# %%
# !git clone https://github.com/tiansiyuan/sh-power.git
# Out:
# Cloning into 'sh-power'...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 87 (delta 17), reused 84 (delta 17), pack-reused 0
# Unpacking objects: 100% (87/87), 6.39 MiB | 5.50 MiB/s, done.

# %%
cd sh-power/notebook
# Out:
# /home/jovyan/sh-power/notebook

# %%
pip install -r requirements.txt
# Out:
# ...
#   Using cached opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
# ...
#   Using cached tensorboard-2.14.0-py3-none-any.whl (5.5 MB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# ...
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# ...
#   Using cached Markdown-3.5.1-py3-none-any.whl (102 kB)
# ...
#   Using cached grpcio-1.60.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# ...
#   Using cached google_auth-2.25.2-py2.py3-none-any.whl (184 kB)
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.35.0
#     Uninstalling google-auth-1.35.0:
#       Successfully uninstalled google-auth-1.35.0
# ...

# %%
ls
# Out:
# data/       hubconf.py          models/            test.py            weights/
# detect.py   imgs/               prepare.py         train_pipeline.py
# Dockerfile  ingest_pipeline.py  README.md*         train.py
# export.py   LICENSE             requirements.txt*  utils/

# %%
mkdir -p VOCdevkit

# %%
cd VOCdevkit
# Out:
# /home/jovyan/sh-power/notebook/VOCdevkit

# %%
# !wget https://jhx.japaneast.cloudapp.azure.com/share/VOC2007.zip
# Out:
# --2023-12-28 00:25:08--  https://jhx.japaneast.cloudapp.azure.com/share/VOC2007.zip
# Resolving jhx.japaneast.cloudapp.azure.com (jhx.japaneast.cloudapp.azure.com)... 20.27.48.0
# Connecting to jhx.japaneast.cloudapp.azure.com (jhx.japaneast.cloudapp.azure.com)|20.27.48.0|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1117970549 (1.0G) [application/zip]
# Saving to: ‘VOC2007.zip’
#
# VOC2007.zip         100%[===================>]   1.04G  28.3MB/s    in 38s
#
# 2023-12-28 00:25:47 (27.9 MB/s) - ‘VOC2007.zip’ saved [1117970549/1117970549]

# %%
# !unzip VOC2007.zip
# Out:
# Archive:  VOC2007.zip
#    creating: VOC2007/
#    creating: VOC2007/Annotations/
#   inflating: VOC2007/Annotations/000000.xml
#   inflating: VOC2007/Annotations/000002.xml
#   inflating: VOC2007/Annotations/000003.xml
#   inflating: VOC2007/Annotations/000004.xml
#   inflating: VOC2007/Annotations/000005.xml
#   inflating: VOC2007/Annotations/000006.xml
#   inflating: VOC2007/Annotations/000007.xml
#   inflating: VOC2007/Annotations/000008.xml
#   inflating: VOC2007/Annotations/000009.xml
#   inflating: VOC2007/Annotations/000010.xml
#   inflating: VOC2007/Annotations/000011.xml
#   inflating: VOC2007/Annotations/000012.xml
#   inflating: VOC2007/Annotations/000013.xml
#   inflating: VOC2007/Annotations/000014.xml
#   inflating: VOC2007/Annotations/000015.xml
#   inflating: VOC2007/Annotations/000016.xml
#   inflating: VOC2007/Annotations/000017.xml
#   inflating: VOC2007/Annotations/000019.xml
#   inflating: VOC2007/Annotations/000020.xml
# ...

# %%
cd ..
# Out:
# /home/jovyan/sh-power/notebook

# %%
# !python prepare.py
# Out:
# Probability: 99
# Probability: 50
# Probability: 88
# Probability: 89
# Probability: 21
# Probability: 56
# Probability: 37
# Probability: 71
# Probability: 7
# Probability: 88
# Probability: 77
# Probability: 86
# Probability: 1
# Probability: 46
# Probability: 3
# Probability: 53
# Probability: 90
# Probability: 42
# Probability: 94
# Probability: 72
# Probability: 24
# Probability: 15
# Probability: 24
# Probability: 49
# Probability: 24
# Probability: 20
# Probability: 23
# Probability: 32
# Probability: 14
# Probability: 75
# Probability: 46
# Probability: 54
# Probability: 97
# Probability: 37
# Probability: 74
# Probability: 17
# Probability: 57
# Probability: 7
# Probability: 51
# Probability: 78
# Probability: 24
# Probability: 85
# Probability: 10
# Probability: 22
# Probability: 41
# Probability: 10
# Probability: 50
# Probability: 41
# Probability: 28
# Probability: 46
# Probability: 27
# Probability: 47
# Probability: 97
# Probability: 79
# Probability: 1
# ...

# %%
# !python train.py --epochs 3 --name exp-1228
# Out:
# github: skipping check (not a git repository)
# YOLOv5 🚀 4f1519d torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3070, 7973.6875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=32, bbox_interval=-1, bucket='', cache_images=False, cfg='models/yolov5s_hat.yaml', data='data/hat.yaml', device='0', entity=None, epochs=3, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp-1228', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp-12284', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=32, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python detect.py --weight runs/train/exp-12284/weights/best.pt   --source  VOCdevkit/images/train/000004.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='VOCdevkit/images/train/000004.jpg', update=False, view_img=False, weights=['runs/train/exp-12284/weights/best.pt'])
# YOLOv5 🚀 4f1519d torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3070, 7973.6875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7056607 parameters, 0 gradients, 16.3 GFLOPS
# image 1/1 /home/jovyan/sh-power/notebook/VOCdevkit/images/train/000004.jpg: 448x640 2 hats, 2 persons, Done. (0.018s)
# Results saved to runs/detect/exp3
# Done. (0.031s)
